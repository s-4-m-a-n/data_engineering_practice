# %%
import requests
import json

# %%
response = requests.get("http://api.currencylayer.com/live?access_key=8ecf90ae2026db3006b62400d3a73d83")

# %%
response = response.json()

# %%
response["quotes"]
# Out:
# {'USDAED': 3.67299,
#  'USDAFN': 88.020932,
#  'USDALL': 111.270054,
#  'USDAMD': 487.693805,
#  'USDANG': 1.798519,
#  'USDAOA': 455.994501,
#  'USDARS': 109.672085,
#  'USDAUD': 1.351543,
#  'USDAWG': 1.80025,
#  'USDAZN': 1.696657,
#  'USDBAM': 1.770759,
#  'USDBBD': 2.014993,
#  'USDBDT': 86.092302,
#  'USDBGN': 1.7716,
#  'USDBHD': 0.376934,
#  'USDBIF': 2046.310128,
#  'USDBMD': 1,
#  'USDBND': 1.354537,
#  'USDBOB': 6.860961,
#  'USDBRL': 5.022701,
#  'USDBSD': 0.99799,
#  'USDBTC': 2.4252704e-05,
#  'USDBTN': 75.952197,
#  'USDBWP': 11.556966,
#  'USDBYN': 3.243309,
#  'USDBYR': 19600,
#  'USDBZD': 2.011553,
#  'USDCAD': 1.259435,
#  'USDCDF': 2011.999622,
#  'USDCHF': 0.932785,
#  'USDCLF': 0.02912,
#  'USDCLP': 803.510323,
#  'USDCNY': 6.361501,
#  'USDCOP': 3818.76,
#  'USDCRC': 640.618917,
#  'USDCUC': 1,
#  'USDCUP': 26.5,
#  'USDCVE': 99.830244,
#  'USDCZK': 22.367019,
#  'USDDJF': 177.660884,
#  'USDDKK': 6.727497,
#  'USDDOP': 54.788096,
#  'USDDZD': 142.541336,
# ...

# %%
key = "8ecf90ae2026db3006b62400d3a73d83"
response2 = requests.get(f"http://api.currencylayer.com/live?access_key={key}")
response2 = response2.json()

# %%
response2
# Out:
# {'success': True,
#  'terms': 'https://currencylayer.com/terms',
#  'privacy': 'https://currencylayer.com/privacy',
#  'timestamp': 1647850323,
#  'source': 'USD',
#  'quotes': {'USDAED': 3.67299,
#   'USDAFN': 88.020932,
#   'USDALL': 111.270054,
#   'USDAMD': 487.693805,
#   'USDANG': 1.798519,
#   'USDAOA': 455.994501,
#   'USDARS': 109.672085,
#   'USDAUD': 1.351543,
#   'USDAWG': 1.80025,
#   'USDAZN': 1.696657,
#   'USDBAM': 1.770759,
#   'USDBBD': 2.014993,
#   'USDBDT': 86.092302,
#   'USDBGN': 1.7716,
#   'USDBHD': 0.376934,
#   'USDBIF': 2046.310128,
#   'USDBMD': 1,
#   'USDBND': 1.354537,
#   'USDBOB': 6.860961,
#   'USDBRL': 5.022701,
#   'USDBSD': 0.99799,
#   'USDBTC': 2.4252704e-05,
#   'USDBTN': 75.952197,
#   'USDBWP': 11.556966,
#   'USDBYN': 3.243309,
#   'USDBYR': 19600,
#   'USDBZD': 2.011553,
#   'USDCAD': 1.259435,
#   'USDCDF': 2011.999622,
#   'USDCHF': 0.932785,
#   'USDCLF': 0.02912,
#   'USDCLP': 803.510323,
#   'USDCNY': 6.361501,
#   'USDCOP': 3818.76,
# ...

# %%
a = {"A":1}

for item in a.items():
    print(item)
# Out:
# ('A', 1)

# %%
if a:
    print("hello")
else:
    print("error")
# Out:
# hello

# %%
a = {"A":1,"b":2}
a.
