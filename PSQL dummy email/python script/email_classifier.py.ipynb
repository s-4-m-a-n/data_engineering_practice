# %% [markdown]
# # Loading Dataset

# %%
import pandas as pd

# %%
email_df = pd.read_csv("email.csv")
email_df.head()
# Out:
#                   primary_email secondary_email
# 0   ["info@exitbeveiliging.nl"]              []
# 1    ["meister@klima-lange.de"]              []
# 2  ["jules@autourduparquet.fr"]              []
# 3      ["hedylapkin@gmail.com"]              []
# 4     ["bucuresti@oltextur.ro"]              []

# %% [markdown]
# # Unpacking Email

# %%
def unpack_email(email_data,columns=["primary_email","secondary_email"]):
    email_list = []
    for col in columns:
        for item in email_data[col]:
            email_ = item.strip('][').replace('"',"").split(', ')
            email_list += [email for email in email_ if email != ""]
    return email_list

# %%
email_ls = unpack_email(email_df)

# %%
email_ls
# Out:
# ['info@exitbeveiliging.nl',
#  'meister@klima-lange.de',
#  'jules@autourduparquet.fr',
#  'hedylapkin@gmail.com',
#  'bucuresti@oltextur.ro',
#  'dennisscheunhage@me.com',
#  'info@korthcapital.com',
#  'popupmediaoy.fi.p.111616-9@docinbound.com',
#  'toimisto@popupmedia.fi',
#  'info@susanne-muehlum.de',
#  'contato@midiasregionais.com.br',
#  'contato@montichelassessoria.com.br',
#  'montichel@montichelassessoria.com.br',
#  'amy.tx.transcare@gmail.com',
#  'info.txmeddevice@gmail.com',
#  'mike.transcare@gmail.com',
#  'support@adsplm.com',
#  'anniekoh.realestate@gmail.com',
#  'dpo@propnex.com',
#  'enquiry@propnex.com',
#  'contact@tamudacultures.org',
#  'contact@tamudaculutres.org',
#  'romain@yachtingexperience.net',
#  'info@enoteca.co.th',
#  'support@adsplm.com',
#  'va@viktorlissy.com',
#  'ad.pearland@isgh.org',
#  'mo@brandparents.com',
#  'contact@tintrel.com',
#  'shanicej10@yahoo.com',
#  'careers@edgecloudworks.com',
#  'paytocert@edgecloudworks.com',
#  'nsunaga@gunma-u.ac.jp',
#  'hello@shouldwego.co',
#  'townofsterlingclerk@gmail.com',
#  'enquiries@edp-au.com',
#  'info@healthywealthymumslife.com',
#  'hpf@skelstedet.dk',
#  'post@skelstedet.dk',
#  'dpo@propnex.com',
#  'enquiry@propnex.com',
#  'iamcatong@gmail.com',
#  'support@punhub.co.uk',
#  'financeiro@logicnet.com.br',
#  'contact@resiliencebijoux.com',
#  'juiceduplashes@gmail.com',
#  'katie@knjart.co.uk',
#  'dpo@propnex.com',
#  'enquiry@propnex.com',
#  'luqmanhakimproperties@gmail.com',
#  'hi@beeketing.com',
#  'sales@green-goo.com',
#  'craftcircus.supplies@gmail.com',
#  'dpo@propnex.com',
#  'enquiry@propnex.com',
#  'maxhuang.projects@gmail.com',
#  'info@company.com',
#  'chris@shadowworkforbeginners.com',
#  'info@dnecommerce.com',
#  'info@jayasuppliesco.com',
#  'info@ideesogni.com',
#  'kadlecek@polymertest.cz',
#  'dpo@propnex.com',
#  'enquiry@propnex.com',
#  'ykk79000@gmail.com',
#  'contact@nvgroup.com',
#  'matthew@mazesolutions.com',
#  'thomas@levieuxcrapaud.fr',
#  'contacto@sanbelasesores.es',
#  'info@nv-group.com.ua',
#  'mccullough.brandt@gmail.com',
#  'poundsand@gmail.com',
#  'info@sportkadernederland.nl',
#  'info@rcrc.org',
#  'info@nv-group.com.ua',
#  'pptaf87@gmail.com',
#  'help@iph.in.ua',
#  'info@ailfon.nl',
#  'info@duyven.nl',
#  'info@seryona.nl',
#  'nh@vivementmardi.fr',
#  'search@rbcdallas.org',
#  '@gmail.com',
#  'gamil.commirmoin100@gmail.com',
#  'jknewchenbal@gmail.com',
#  'jknewschenab001@gamil.com',
#  'jknewschenab001@gmail.com',
#  'jknewschenab@gmail.com',
#  'service@jun-mao.com.tw',
#  'soporte@purifiermd.com',
#  'contactkayasole@gmail.com',
#  'info@caseupstore.com',
#  'info@besazmining.com',
#  'wordpress@besazmining.com',
#  'info@cloud9shop.pl',
#  'info@nordicwoods.nl',
#  'search@rbcdallas.org',
#  'inquiries@edensalt.com',
#  'permanentmakeupsupplies@hotmail.com',
#  'kclarkeny@gmail.com',
#  'information@info.com',
#  'support@brightness-hosting.com',
#  '713kontakt@7element.pl',
#  '7element13@gmail.com',
#  'kontakt@7element.pl',
#  'viet.nq90@gmail.com',
#  'hello@gographer.com',
#  'hellogographer@gmail.com',
#  'information@info.com',
#  'support@brightness-hosting.com',
#  'info@kitesurfgrancanaria.com',
#  'info@surfgrancanaria.com',
#  'info@hootyshomeroom.com',
#  'info@xtc.com.hk',
#  'sales@xtc.com.hk',
#  'kaleva.vl@mail.ru',
#  'support@toyotakendari.id',
#  'customerservice@dollbeauty.com',
#  'tenshoku@kyuujin.com',
#  'info@matchwerkt.nl',
#  'privacy@matchwerkt.nl',
#  'barucha@teder.com',
#  'frank@microsecure.com.au',
#  'info@abp.com',
#  'jerryh@abp.com',
#  'privacy@abp.com',
#  'shaneknight@marlboroughcomms.com',
#  'walterw@abp.com',
#  'crazykabboy6@gmail.com',
#  'info@seaval.com',
#  'info@saintmp.com',
#  'info@etibbouwmeester.nl',
#  'gabriel@idolos.mx',
#  'hola@idolos.mx',
#  'legal@idolos.mx',
#  'info@soccerstarcoaching.co.uk',
#  'k.walker@amrmarketinggroup.com',
#  'info@reisdoordezorg.nl',
#  'ayurjeet20@gmail.com',
#  'ragamjogja@gmail.com',
#  'gracie@gracielushihtzu.com',
#  'ragamjogja@gmail.com',
#  'bethegoaty@gmail.com',
#  'hi@clubbioman.com',
#  'arganmidas.com.ua@gmail.com',
#  'info@arganmidas.com.ua',
#  'biuro@dom-plonsk.pl',
#  'rmm@readymachinery.com',
#  'atendimento@impactodobrasil.com.br',
#  'contato@dramagalireis.com.br',
#  'hello@divicoach.com',
#  'dogtownhots@gmail.com',
#  'ladlesportadv@gmail.com',
#  'datenschutz@bluquist.com',
#  'hello@bluquist.com',
#  'go88web1@gmail.com',
#  'admin@shinkosyoten.co.jp',
#  'dsirstad@dsministries.com',
#  'rose@furryfurends.com',
#  'alexi.delcanto@uai.cl',
#  'hi@thrill.coffee',
#  'order@thrill.coffee',
#  'wholesale@thrill.coffee',
#  'a-s.hagspiel@vol.at',
#  'gabriele.blank@sulzberg.at',
#  'pfarramt@haus-zur-marienlinde.at',
#  'pfarramt@pfarre-sulzberg.at',
#  'jolielaideau@gmail.com',
#  'info@charlieandmarley.net',
#  'info@fareh.hostnewera.ca',
#  'info@vafa.hostnewera.ca',
#  'adblinkmedia@gmail.com',
#  'rogerjameselsgood@gmail.com',
#  'contact@electronbike-frejus.fr',
#  'electronbikefrejus@gmail.com',
#  'magnoliamidleton34@gmail.com',
#  'serviceclient@iandkbeauty.com',
#  'support@mileyah.com',
#  'samuelsubba077@gmail.com',
#  'sunakhari.darj@gmail.com',
#  'agnija@ff-group.lv',
#  'au@ff-group.lv',
#  'info.latvija.riga@radissonblu.com',
#  'info@larocca.lv',
#  'info@studio69.lv',
#  'ivo@ff-group.lv',
#  'muzejs@ldz.lv',
#  'kontakt@design-plast.pl',
#  'kontakt@designplast.pl',
#  'goodmarkagencies@hotmail.com',
#  'mail@masonicbiker.ch',
#  'info@shopyitalia.it',
#  'dataprotection@isi.com',
#  'dataprotection@isiww.com',
#  'info@isiww.com',
#  'dpi.homeinspections@gmail.com',
#  'contact@powerlife4u.com',
#  'contact@redberryfashion.com',
#  'gabriel@idolos.mx',
#  'hola@idolos.mx',
#  'legal@idolos.mx',
#  'ante@kadigital.se',
#  'kevin@kadigital.se',
#  'datenschutz@bluquist.com',
#  'hello@bluquist.com',
#  'kevin@kadigital.se',
#  'info@ramadhanpublications.co.uk',
#  'slaughterhouzemma@gmail.com',
#  'goodmarkagencies@hotmail.com',
#  'ante@kadigital.se',
#  'gestion@tailore.es',
#  'naturescreationcda@gmail.com',
#  'post@redl-communication.com',
#  'louisa@woodviewhrm.com',
#  'info@ramadhanpublications.co.uk',
#  'gmsfpho@gmail.com',
#  'info@syllastria.gr',
#  'brittany@sharedhope.org',
#  'savelives@sharedhope.org',
#  'newcoppertreeboard@gmail.com',
#  'marketing@uncleg.com',
#  'shop@uncleg.com',
#  'dennis@firstsipbrewbox.com',
#  'ﬁcusgreens@yahoo.com',
#  'adam@spiralgrooverecords.com',
#  'info@maintenanceassistant.com',
#  'info@sales-search.com',
#  'principalvcas@gmail.com',
#  'torerome@gmail.com',
#  'kontakt@wojciechzalewski.pl',
#  'admin@drlynnburmeister.com.au',
#  'info@enterthewild.life',
#  'rustad@rustad-transport.no',
#  'info@gwandlarei.de',
#  'carine@bedriftskonsulent.no',
#  'hi@beeketing.com',
#  'xxvi.supply@gmail.com',
#  'info@zamichem.co.ke',
#  'info@behradlift.com',
#  'metrojaminan@gmail.com',
#  'info@breatheplus.co',
#  'info@georgiakateboutique.com',
#  'complaints.lpt@yahoo.com',
#  'info.loveplaytoys@gmail.com',
#  'ninfo.loveplaytoys@gmail.com',
#  'orders@loveplaytoys.com',
#  'info@marketfuelmedia.com',
#  'jussi.jarvinen@sisustusstudio.fi',
#  'sari.valasvuo@sisustusstudio.fi',
#  'compro_team@ciuss.com',
#  'ptsaffalyamitrautama@gmail.com',
#  'inquire@hellocheshire.com',
#  'popolkam@mail.ru',
#  'info@excav8te.ca',
#  'compro_team@ciuss.com',
#  'ptsaffalyamitrautama@gmail.com',
#  'kontakt@naturnetzerk.ch',
#  'kontakt@naturnetzwerk.ch',
#  'customercare@buylowtactical.com',
#  'info@bioseet.com',
#  'ajohn@nspiremagazine.com',
#  'dustin@kootenaititle.com',
#  'jamescostello@umpquabank.com',
#  'jdoty@windermere.com',
#  'msears@paynewest.com',
#  'thethurmanater@gmail.com',
#  'wallacewealth@gmail.com',
#  'info@gearfc.com',
#  'sales@gearfc.com',
#  'support@blazethemes.com',
#  'info@fortheloveofpickles.com',
#  'info@tpu-pb.de',
#  'contact@coletivoamarelo.com',
#  'info@moika.si',
#  'informacion@florameshop.com',
#  'pedidos@florameshop.com',
#  'ventapormayor@florameshop.com',
#  'contacto@rdcava.com',
#  'diego.cava@hotmail.com',
#  'brad@atomicstudio.io',
#  'career@atomicstudio.io',
#  'info@atomicstudio.io',
#  'it@zinnerlogistics.com',
#  'comunicazione@valuemedia.it',
#  'info@ramkvillahastklinik.se',
#  'info@de-ebenist.nl',
#  'info@swell.lv',
#  'enquiries@blenheimdb.co.uk',
#  'info@bellizza.com',
#  'privacy@noah-tennis.com',
#  'info@tcf-uk.org',
#  'info@jchuidkliniek.nl',
#  'ashley@theupdateagency.com',
#  'admin@portabletoilethire.net',
#  'hello@babyloncollectibles.com',
#  'it@zinnerlogistics.com',
#  'administracion@grupogomez.com.pa',
#  'previni.consultoria@hotmail.com',
#  'cairns@genovese.com.au',
#  'enquiries@genovese.com.au',
#  'info@genovese.com.au',
#  'sales@genovese.com.au',
#  'service@genovese.com.au',
#  'lezz_kantoor@outlook.com',
#  'glamjor@gmail.com',
#  'trauzeugen@heiterehochzeit.ch',
#  'rnoren@soundchristianacademy.org',
#  'info@nemetceginfo.hu',
#  'info@nvmburo.de',
#  'gisela.schutti@fh-ooe.at',
#  'l12345@fhooe.at',
#  'p12345@fhooe.at',
#  'pv@fh-ooe.at',
#  's1234567890@fhooe.at',
#  'servicedesk@fh-ooe.at',
#  'novellaprints@gmail.com',
#  'tuyhoafoods@gmail.com',
#  'info@theheartyoil.com',
#  'cvah@cvah.nl',
#  'info@vbw.nu',
#  'hello@tatildefethiye.com',
#  'billing@mellhost.com',
#  'jimmellsamuels@mellhost.com',
#  'mellhost@mellhost.com',
#  'support@mellhost.com',
#  'admin@nuvolifecare.com',
#  'info@old.plcgoods.com',
#  'info@plcgoods.com',
#  'hello@cheekylittlemonkeysjewellery.com.au',
#  'uneimages@gmail.com',
#  'info@mimosa-handgemaakt.nl',
#  'drpedro@medfamily.com.br',
#  'info@espacepekan.com',
#  'info@snaxico.com',
#  'beheer@naber.nl',
#  'ssdfutbolclubsrl@gmail.com',
#  'info@lafarmtoschool.org',
#  'ssdfutbolclubsrl@gmail.com',
#  'sales@worldship.com.sg',
#  'contact@starnemesis.com',
#  'contactstarnemesis@gmail.com',
#  'info@neopromosindo.com',
#  'info@ofenfuchs.de',
#  'info@rel-rakennus.fi',
#  'daniela.goette@unitybox.de',
#  'info@zonasegura.com.mx',
#  'baselschweizinfo@vectoris.ch',
#  'info@vectoris.ch',
#  'hello@lalo-skincare.com',
#  'legal@lalo-skincare.com',
#  'legal@this-is-lalo.com',
#  'contact@yourstore.com',
#  'info@electro.com',
#  'sales@keemstar.co.ke',
#  'futlaa.ltd@gmail.com',
#  'qamar@cafemax.uk',
#  'contact@opensi.co',
#  'benoteworthy@hamelinbrands.com',
#  'vanzari@antica-pizza.ro',
#  'futlaa.ltd@gmail.com',
#  'info@curezz.com',
#  'info@lolmission.org',
#  'jotudescrubs@gmail.com',
#  'support@afroscrubs.com',
#  'support@jotudescrubs.com',
#  'yvo@zzbk1.ua',
#  'booking@utternofficial.com',
#  'info@utternofficial.com',
#  'customerservice@bonblissity.com',
#  'info@bonblissity.com',
#  'geri@captureyourpath.com',
#  'info@acpersepolis.com',
#  'info@domodesk.com',
#  'info@sensalora.com',
#  'info@sensarola.com',
#  'hello@niallflynn.ie',
#  'contacto@lemuhandmade.cl',
#  'studiotinyloft@gmail.com',
#  'tanya@studiotinyloft.ca',
#  'dan.rubio@sabbsolymangos.mx',
#  'jeral.bautista@sabbsolymangos.mx',
#  'sel.bautista@sabbsolymangos.mx',
#  'victor.pavon@sabbsolymangos.mx',
#  'arkyenpharmaceuticals99@gmail.com',
#  'samuelsubba077@gmail.com',
#  'sunakhari.darj@gmail.com',
#  'info@protegetuvida.eu',
#  'info@maribformp.com',
#  'contact@letom-sport.com',
#  'order@akustikafactory.id',
#  'info@aluag.ch',
#  'hello@integritytree.ca',
#  'info@chahalseeds.com',
#  'bookdesign@davidmoratto.com',
#  'info@birrulwalidainislamicschool.sch.id',
#  'info@marvinkuhr.com',
#  'kuhrmarvin@gmail.com',
#  'botextra341@gmail.com',
#  'email@gmail.com',
#  'youremails@gmail.com',
#  'info@phloxshop.com',
#  'info@shanooenterprises.com',
#  'info@actishape.ie',
#  'sales@actishape.ie',
#  'biz@nerdsblock.com',
#  'administracion@iberopistacho.com',
#  'sousaku@atelier.co.jp',
#  'joe@ignitevisibility.com',
#  'kontakt@anwaelte-darmstadt.de',
#  'timwarnecke0@gmail.com',
#  'hello@litlco.com',
#  'info@transition-cycle.co.jp',
#  'info@clinicalcatalyst.com',
#  'enquiries@projectpilots.net',
#  '@gmail.com',
#  'gamil.commirmoin100@gmail.com',
#  'jknewchenbal@gmail.com',
#  'jknewschenab001@gamil.com',
#  'jknewschenab001@gmail.com',
#  'jknewschenab@gmail.com',
#  'admin@7zile.info',
#  '0001az@myprose.com',
#  '0003az@myprose.com',
#  '0005fl@myprose.com',
#  '0006tn@myprose.com',
#  '0007nj@myprose.com',
#  '0008il@myprose.com',
#  '0009co@myprose.com',
#  '0010mn@myprose.com',
#  '0014fl@myprose.com',
#  '0016tn@myprose.com',
#  '0023ga@myprose.com',
#  '0025gm@myprose.com',
#  '0031gm@myprose.com',
#  '0032gm@myprose.com',
#  '0033wi@myprose.com',
#  '0035tx@myprose.com',
#  '0038gm@myprose.com',
#  '0039gm@myprose.com',
#  '0041gm@myprose.com',
#  '0041mo@myprose.com',
#  '0042nd@myprose.com',
#  '0043gm@myprose.com',
#  '0044mn@myprose.com',
#  '0049wi@myprose.com',
#  'afascientto@myprose.com',
#  'ajones@myprose.com',
#  'bbuchholtz@myprose.com',
#  'bcitron@myprose.com',
#  'bgrinaker@myprose.com',
#  'bkneeshaw@myprose.com',
#  'bzweig@myprose.com',
#  'cconlee@myprose.com',
#  'cflom@myprose.com',
#  'dcoats@myprose.com',
#  'dgalloway@myprose.com',
#  'dnovak@myprose.com',
#  'eebsworth@myprose.com',
#  'eromero@myprose.com',
#  'jcoats@myprose.com',
#  'jgrinaker@myprose.com',
#  'jmarkowicz@myprose.com',
#  'jzalud@myprose.com',
#  'kgilbertson@myprose.com',
#  'khalvorson@myprose.com',
#  'kkimmel@myprose.com',
#  'lgreenhill@myprose.com',
#  'mgilbertson@myprose.com',
#  'mhixon@myprose.com',
#  'mstrulowitz@myprose.com',
#  'prosetowson@gmail.com',
#  'sbuchner@myprose.com',
#  'shixon@myprose.com',
#  'skimmel@myprose.com',
#  'support@myprose.com',
#  'tdalsin@myprose.com',
#  'tdisco@myprose.com',
#  'info@talktocass.com',
#  'bobvandelm@pandora.be',
#  'sharecareawards@sharecare.com',
#  'info@ehtisham.net',
#  'mehtisham235@gmail.com',
#  'info@ulu.com',
#  'info@ulu.com.',
#  'info@utopianation.com.',
#  'appliancespartsonline@yahoo.com',
#  'stellarlawnpest@gmail.com',
#  'info@copperfiddle.com',
#  'ceo@unityeducationtrust.uk',
#  'office@hig.unity-ed.uk',
#  'kontakt@aw-architektur.info',
#  'darren@odysseycoffeeroasters.com',
#  'out.patrick@odysseycoffeeroasters.com',
#  'patrick@odysseycoffeeroasters.com',
#  'info@armyofjustice.org',
#  'info@d10multimedia.es',
#  'allesklar@herrklar.de',
#  'info@betriebsratzitate.de',
#  'info@deutschedesigns.com',
#  'labfriendinfo@gmail.com',
#  'info@thaneycpa.com',
#  'admin@fxescalators.com',
#  'info@carolino.com',
#  'info@carolino.es',
#  'privacy@carolino.es',
#  'tienda@carolino.es',
#  'info@paido.org',
#  'bryce.supplement@gmail.com',
#  'contact@suite6studios.com',
#  'primas@07motorsport.de',
#  'humedalrenaca@gmail.com',
#  '01coversme@gmail.com',
#  'coverme@gmail.com',
#  'executives@brodardsearch.com',
#  'info@brodardsearch.com',
#  'watchbaoanh@gmail.com',
#  'rd.surreysussex@camra.org.uk',
#  'shb@camrasurrey.org.uk',
#  'servicioyatencion@kapital.la',
#  'labfriendinfo@gmail.com',
#  'americas@servy.us',
#  'ann@servy.us',
#  'apac@servy.us',
#  'avi@servy.us',
#  'camille@servy.us',
#  'emea@servy.us',
#  'ernie@servy.us',
#  'greg@servy.us',
#  'help@getgrab.com',
#  'jarod@servy.us',
#  'jason@servy.us',
#  'jeff.sidfrid@servy.us',
#  'jeff@servy.us',
#  'lauryn@servy.us',
#  'mark@servy.us',
#  'marketing@getgrab.com',
#  'media@servy.us',
#  'michael@servy.us',
#  'mimi@servy.us',
#  'partner@servy.com',
#  'partner@servy.us',
#  'rahim@servy.us',
#  'sarah@servy.us',
#  'shannon@servy.us',
#  'wade@servy.us',
#  'info@oneillbergadocpas.com',
#  'lisa.timmins@gmail.com',
#  'americas@servy.us',
#  'ann@servy.us',
#  'apac@servy.us',
#  'avi@servy.us',
#  'camille@servy.us',
#  'emea@servy.us',
#  'ernie@servy.us',
#  'greg@servy.us',
#  'help@getgrab.com',
#  'jarod@servy.us',
#  'jason@servy.us',
#  'jeff.sidfrid@servy.us',
#  'jeff@servy.us',
#  'lauryn@servy.us',
#  'mark@servy.us',
#  'marketing@getgrab.com',
#  'media@servy.us',
#  'michael@servy.us',
#  'mimi@servy.us',
#  'partner@servy.com',
#  'partner@servy.us',
#  'rahim@servy.us',
#  'sarah@servy.us',
#  'shannon@servy.us',
#  'wade@servy.us',
#  'contact@carvic.de',
#  'sales@centraltent.com',
#  'support@somethingcasual.ca',
#  'watchbaoanh@gmail.com',
#  'info@queenshotelbrighton.com',
#  'contact@siteag.com',
#  'ernest@jecobac.de',
#  'ngavq.hoangnammobile@gmail.com',
#  'caseydillow36@icloud.com',
#  'paving_plus@yahoo.com',
#  'assistenza@borgtech.eu',
#  'info@borgtech.eu',
#  'cmd@czecheverything.co.uk',
#  'gary@cullor.com',
#  'investorservices@apartmentvestors.com',
#  'spencer@apartmentvestors.com',
#  'dentalgroup@annarborsmiles.com',
#  'bdavis@ecosensecompany.com',
#  'fjcolombiapr@hotmail.com',
#  'info@shadeworks.com',
#  'info@hawhaw.co.uk',
#  'uksales@hawhaw.co.uk',
#  'mcheryl@cheryl-ford-photography.com',
#  'info@timelinepublishinginc.com',
#  'kittenishgirljess@gmail.com',
#  'sngsngsng09@gmail.com',
#  'julie@julies-secret-stash.com',
#  'trauzeugen@heiterehochzeit.ch',
#  'bso@skauting.sk',
#  'cej@skauting.sk',
#  'international@skauting.sk',
#  'info@kinosalon.dk',
#  'hello@themenectar.com',
#  'info@bsa-akademie.de',
#  'craftynestdesigns@gmail.com',
#  'info@sector5.jp',
#  'info@sigmalocks.com',
#  'revivedancewear.ca@gmail.com',
#  'info@stage4.c2-cl.de',
#  'info@imentertainment.vn',
#  'mllegeorgesand@gmail.com',
#  'info@darrickinternationalschool.com',
#  'atendimento@usenycnyc.com',
#  'admin@cpaccount.com.sg',
#  'enquiry@cpaccount.com.sg',
#  'sales@binlcollections.com',
#  'sample@mycompany.com',
#  'support@surveysparrow.com',
#  'info@apiarista.de',
#  'form1docs@lynchmeyer.com.au',
#  'lbielby@lynchmeyer.com.au',
#  'smortimer@lynchmeyer.com.au',
#  'info@togetherwe.uk',
#  'wisedent1@gmail.com',
#  'adrienner.art@gmail.com',
#  'support@mizanenterprises.com',
#  'info@beyondlawn.ca',
#  'info@quikfittyres.com.au',
#  'hadi@naturalcarenc.com',
#  'info@naturalcare-nc.com',
#  'info@naturalcare.care',
#  'info@vakantiehuisjebijboerderij.nl',
#  'info@dearchitectvra.com',
#  'info@indesigncorp.com',
#  'info@aurednik.com',
#  'info@aurednik.de',
#  'botextra341@gmail.com',
#  'nagatamitra@hotmail.com',
#  'sales@nagatamitra.com',
#  'info@kapsalonlucienne.nl',
#  'confioenmi8@gmail.com',
#  'info@ketodropschile.com',
#  'estubble@hotmail.com',
#  'thewell@intervarsity.org',
#  'info@thienan.asia',
#  'goodnewsdaily@aol.com',
#  'admin@huddlestoncourt.info',
#  'administrator@esqwire.net',
#  'kontakt@leasingoo.se',
#  'info@louisvillejockeyclub.com',
#  'info@carsandguitars.biz',
#  'info@valkyriesdesigns.ca',
#  'valkyriesdesigns@gmail.com',
#  'info@bpg-consultants.com',
#  'revive_coordination@tractebel.engie.com',
#  'lene@jaxwax.dk',
#  'prodex-rgpd@prodex-elastomeres.com',
#  'rgpd@prodex.fr',
#  'enquiries.asean@bluescope.com',
#  'enquiries.indonesia@bluescope.com',
#  'enquiries.malaysia@bluescope.com',
#  'enquiries.thailand@bluescope.com',
#  'enquiries.vietnam@bluescope.com',
#  'enquiry@nsbluescope.com',
#  'lysaght.singapore@bluescope.com',
#  'myanmar@bluescopesteel.com',
#  'info@somebliss.com',
#  'holyworld2014@gmail.com',
#  'info@puntacanatravel.org',
#  'rachel@rachelbraywriting.com',
#  'info@distr51.ru',
#  'annel@gmail.com.',
#  'o.@r.ar',
#  'wideanglechannel@gmail.com.',
#  'transport@orbatransport.com',
#  'ninfo@hdesign-fabric.art',
#  'yourinnergardenhealthcoach@gmail.com',
#  'info@sankou-densetsu.jp',
#  'john@example.jp',
#  'bolanos@banios-angelrubio.com',
#  'info@ar-superficiessolidas.com',
#  'internacional@agpd.es',
#  'midia@oimeliga.com.br',
#  'suporte@oimeliga.com.br',
#  'hello@kendesklifestyle.com',
#  'peter@xionel.net',
#  'smurph929@earthlink.net',
#  'ayuda@yom.la',
#  'info@yogicastro.com',
#  'info@concentricstorage.com',
#  'info@multis.is',
#  'info@wand-massishaus.de',
#  'info@wand-massivhaus.de',
#  'contact@meetingdev.com',
#  'kaliningrad@rezerv-rus.ru',
#  'info@cantech.com.vn',
#  'biz@boomintertribal.com',
#  'careers@boomintertribal.com',
#  'david.bonner@clarkdalefitness.com',
#  'info@wand-massishaus.de',
#  'info@wand-massivhaus.de',
#  'info@personalizeyouritems.com',
#  'orders@personalizeyouritems.com',
#  'ayuda@yom.la',
#  'info@teatro-esel.de',
#  'info@theblackstairs.ie',
#  'hello@kendesklifestyle.com',
#  'onaleerose22@gmail.com',
#  'alan@anesprof.com',
#  'david.bonner@clarkdalefitness.com',
#  'don.grieser@gmail.com',
#  'obivaem178@yandex.ru',
#  'sazeqstore@gmail.com',
#  'support@myheroacademiamanga.net',
#  'hello@attentioncrm.com',
#  'info@salesforce.hu',
#  'info@citywideroofers.ie',
#  'contato@piscinafacil.com.br',
#  'loja@piscinafacil.com.br',
#  'info@letterkennycu.ie',
#  'service@everklyn.com',
#  'info@gameparty.com',
#  'info@wand-massishaus.de',
#  'info@wand-massivhaus.de',
#  'power@solar.capetown',
#  'email@yourdomain.co.uk',
#  'info@tektonics.co.uk',
#  'info@tektonics.cu.uk',
#  'info@mslaspullas.com',
#  'b.neve@t-online.de',
#  'familieliebherr@aol.com',
#  'smc-sonthofen@outlook.de',
#  'info@yogicastro.com',
#  'info@o4o.org',
#  'botextra341@gmail.com',
#  'sales@indianyouthhype.com',
#  'talent@indianyouthhype.com',
#  'sales@maldiveorganics.com',
#  'mariarubiohandbags@gmail.com',
#  'nicholas.watkins@q4management.com',
#  'catalogs@douglaspads.com',
#  'info@douglaspads.com',
#  'info@citywideroofers.ie',
#  'info@armensgameroom.ca',
#  'sales@armensgameroom.ca',
#  'info@lhommequifaitdesarbres.ca',
#  'support@tropicalsprouts.com',
#  'info@radiantinquestofgold.com',
#  'admin@saas-services.com',
#  'mail@honey-trap.info',
#  'info@frostedfate.com',
#  'info@woodonwall.se',
#  'gandur@gandur.is',
#  'linstantcacao@gmail.com',
#  'bdrumm@catholicbishops.ie',
#  'columbacentre@iecon.ie',
#  'info@catholicbishops.ie',
#  'info@fkandb.com',
#  'kula@kula.is',
#  'support@summerbock.com',
#  'support@summerbock.com.',
#  'indies@indepreneur.io',
#  'support@indepreneur.io',
#  'info@nuancashmere.com',
#  'sales@nuancashmere.com',
#  'support@starapps.studio',
#  'torben@mogensen.co',
#  'contact@gopurepod.com',
#  'info@blocenterprises.com',
#  'jim@blocenterprises.com',
#  'caseydillow36@icloud.com',
#  'paving_plus@yahoo.com',
#  'reclutamiento@jvsegurosyfianzas.com',
#  'admin@k.org.mx',
#  'alguraak@gmail.com',
#  'mike@anchoragewinehouse.com',
#  'borundaconcrete@gmail.com',
#  'info@gocook.net',
#  'webon@qodeinteractive.com',
#  'st.job.bc@gmail.com',
#  'jules@juleswithtools.co.uk',
#  'music@reana-and-her-soulmates.ch',
#  'sales@burkedecor.com',
#  'christopher@naturalcarbon.com.au',
#  'info@specialtysearchgroup.com',
#  'shaun@rightstepsolutions.com',
#  'contacto@universidadempresa.com',
#  'info@powerstamp.org',
#  'najmainstitute@gmail.com',
#  'parkrec@stallingsnc.org',
#  'info@getnooks.com',
#  'info@dashutsu.com',
#  'yuuto@coruna.biz',
#  'admin@gadjahmada.co.id',
#  'biuro@incantesimo.pl',
#  'jessicahightower.art@gmail.com',
#  'editor@hlrecord.org',
#  'info@stea.co',
#  'mnoriega@stea.co',
#  'ballarat@bowserbean.com.au',
#  'breakwater@bowserbean.com.au',
#  'canadian@bowserbean.com.au',
#  'careers@bowserbean.com.au',
#  'condobolin@bowserbean.com.au',
#  'deniliquin@bowserbean.com.au',
#  'epsom@bowserbean.com.au',
#  'euroa@bowserbean.com.au',
#  'healesville@bowserbean.com.au',
#  'kilmore@bowserbean.com.au',
#  'kyabram@bowserbean.com.au',
#  'kyneton@bowserbean.com.au',
#  'mansfield@bowserbean.com.au',
#  'moama@bowserbean.com.au',
#  'strathfieldsaye@bowserbean.com.au',
#  'whitehills@bowserbean.com.au',
#  'info@solo-musica.de',
#  'info@valveslab.com',
#  'lukas@etobigrow.ca',
#  'stefan@etobigrow.ca',
#  'christy@christytylerphotography.com',
#  'ithero@symphonysummit.com',
#  'peakartsalive@gmail.com',
#  'hello@karaboclothing.co.uk',
#  'karaboclothing@hotmail.co.uk',
#  'support@starapps.studio',
#  'info@poliplast.net',
#  'info@test-p-studio.it.net',
#  'info@mrflax.com.au',
#  'botavalife@gmail.com',
#  'hartzelldesigns@gmail.com',
#  '2110jrv@gmail.com',
#  'wp.natt.th@gmail.com',
#  'contact@ssit.io',
#  'peakartsalive@gmail.com',
#  'suporte@futuradesign.inf.br',
#  'info@allyforcongress.com',
#  'ashevilleplaystoday@gmail.com',
#  'reservations@granvilleislandhotel.com',
#  'botavalife@gmail.com',
#  'info@neveweb-agency.com',
#  'support@sandandsky.com',
#  'suporte@futuradesign.inf.br',
#  'hello@kseniahomedesign.com',
#  'ksenia@kseniahomes.com',
#  'admin@thepurpledogdefiance.com',
#  'info@citycorona.de',
#  'info@concentricstorage.com',
#  'ashevilleplaystoday@gmail.com',
#  'info@pekcanhotel.com',
#  'info@isasmenorca.com',
#  'recruitment@veracityts.com.au',
#  'info@allyforcongress.com',
#  'mail@orgelbauwerkstaette.de',
#  'info@mundolibre.com.ar',
#  'sales@trickrc.com.au',
#  'contacto@cossmopharma.pe',
#  'contacts@cossmopharma.com',
#  'mali.lsikora@wp.pl',
#  'info@hex-group.eu',
#  'info@sovice.si',
#  'kheirandish.takin@gmail.com',
#  'mail@jf-vilarformoso.pt',
#  'kheirandish.takin@gmail.com',
#  'info@misraicesgourmet.com',
#  'info@misraicesoliveoil.com',
#  'nfo@misraicesoliveoil.com',
#  'hadrien.clouet@univ-toulouse.fr',
#  'stuttgart@vgsd.de',
#  'nico@authentjc.com',
#  'info@entech.com',
#  'info@kapawshop.se',
#  'info@verkoopvink.nl',
#  'voorbeeld@hotmail.nl',
#  'info@coltoo.fr',
#  'kontakt@comeback-stronger.de',
#  'mentaltraining@andrezuder.com',
#  'yourmail@info.com',
#  'customerbookings@silverlake.associates',
#  'maywang@dominionqc.ca',
#  'info@elanvie.com',
#  'info@boxposh.com',
#  'office@minervajewelry.co',
#  'support@twilightonline.co',
#  'customerbookings@silverlake.associates',
#  'hadrien.clouet@univ-toulouse.fr',
#  'email@dieholzschuh.ch',
#  'info@home-interier.eu',
#  'quynhthuy.lively@gmail.com',
#  'huyle215@gmail.com',
#  'info@maselfstorage.org',
#  'events@tailspinbrewing.co',
#  'jack@tailspinbrewing.co',
#  'info@irongateexhibition.com',
#  'pn@pn-me.com',
#  'herbelieve2@gmail.com',
#  'kontakt@ganjalife.de',
#  'vansbags.id@gmail.com',
#  'contactjuublie@gmail.com',
#  'hello@anisu.in',
#  'anna.nevarez@gmail.com',
#  'info@best-european-health-spas.com',
#  'hello@boxteq.com',
#  '20contact@kayartie.com',
#  'contact@kayartie.com',
#  'crnews.online@gmail.com',
#  'info@myfleetlatam.com',
#  'saasland@gmail.com',
#  'alejandro.gonzalez@zanartu.cl',
#  'amunoz@zanartu.cl',
#  'correo@zanartu.cl',
#  'dgonzalez@zanartu.cl',
#  'mariapaz.vargas@zanartu.cl',
#  'secretaria.concepcion@zanartu.cl',
#  'secretaria.coyhaique@zanartu.cl',
#  'secretaria.rancagua@zanartu.cl',
#  'secretariagiv@zanartu.cl',
#  'hello@abpadvocates.com',
#  'mail@sharegoodness.org',
#  'smartydayshop@gmail.com',
#  'privacidaddatos.aviso@gmail.com',
#  'mostafaapkfon@gmail.com',
#  'charles@aerialps.com',
#  'getsales@truwerks.net',
#  'contact@mydocuc.com',
#  'contact@yenchingmidlothian.com',
#  'info@defila.co.id',
#  'gdpr@ngngenterprises.com',
#  'info@ngngenterprises.com',
#  'jornadadobem22@gmail.com',
#  'bfsaa@msu.edu',
#  'jorneantoni@antonic.nl',
#  'mike@mptconcrete.co.nz',
#  'contato@prootorrinos.com.br',
#  'kontakt@lubon-lokalnie.pl',
#  'hello@buybettergadget.com',
#  'hello@buybettergadgets.com',
#  'contato@prootorrinos.com.br',
#  'comite.incoop@gmail.com',
#  'xyz@xxx.com',
#  'dani@jfashionista.com',
#  'deneice@animematsuri.com',
#  'saudphp@gmail.com',
#  'hello@shopkhangura.com',
#  'infonctiindia@gmail.com',
#  'info@landluvt.com',
#  'info@vareseparquet.it',
#  'arnt.scheele@qvisten.no',
#  'arnt@twistedmind.no',
#  'furusato@kitaguni.tv',
#  'bestuur@carnavalzevenbergen.nl',
#  'bult@carnavalzevenbergen.nl',
#  'fotos@carnavalzevenbergen.nl',
#  'groteoptocht@carnavalzevenbergen.nl',
#  'info@carnavalzevenbergen.nl',
#  'kinderoptocht@carnavalzevenbergen.nl',
#  'liedjesfestival@carnavalzevenbergen.nl',
#  'versieringswedstrijd@carnavalzevenbergen.nl',
#  'website@carnavalzevenbergen.nl',
#  'info@bridgeproperty.com',
#  'media@bridgeproperty.com',
#  'sharon@sjur.nl',
#  'thomas@sjur.nl',
#  'marketing@poonapressings.com',
#  'abelard.hernandez@gmail.com',
#  'contato@emagrecanamedidacerta.com',
#  'contact@karyagroup.co.id',
#  'info@techbahas.com',
#  'rob@macalisterbrewingcompany.com.au',
#  'holysmokeecoincense@gmail.com',
#  'manga-blog@igmonostone.com',
#  'geeksblogging@gmail.com',
#  'a.baginska@mevepa.pl',
#  'biuro@mevepa.pl',
#  'contact@phoenicianres.com',
#  'arvid.myrold@etac.com',
#  'bard.evensen@etac.com',
#  'kjell.fadnes@etac.com',
#  'mathias.kjaer@etac.com',
#  'odd.vidar.borosund@etac.com',
#  'ola.hammervoll@etac.com',
#  'per.jan.nepstad@etac.com',
#  'steffen.trangsrud@etac.com',
#  'svein.pedersen@etac.com',
#  'thomas.foslund.harila@etac.com',
#  'kevin.stott@liverpoolcathedral.org.uk',
#  'mllegeorgesand@gmail.com',
#  'shop@liverpoolcathedral.org.uk',
#  'full.si@silverlines.info',
#  'apohairs@gmail.com',
#  '20@cleoscatering.com',
#  'apohairs@gmail.com',
#  'quotenwilly@gmail.com',
#  'support@quotenwilly.com',
#  'info@rvhotels.es',
#  'lopd@gruprv.es',
#  'reservas@hotelgolfcostabrava.es',
#  'towerroadbaptistchurch@hotmail.com',
#  'admin@50ymasalla.com',
#  ...]

# %% [markdown]
# # Fetch email prefix

# %%
import re

# %%
def fetch_email_prefix(email_list):
    email_l = []
    email_pattern = re.compile("([\w|\d| ! # $ % & ' * + \- \/ = ? ^ _ ` . { | } ~]+)@.*",re.IGNORECASE)
    for email in email_list:
        prefix = re.search(email_pattern, email)
        if prefix:
            email_l.append(prefix.group(1))
    return email_l

# %%
email_prefix_list = fetch_email_prefix(email_ls)

# %%
email_prefix_list
# Out:
# ['info',
#  'meister',
#  'jules',
#  'hedylapkin',
#  'bucuresti',
#  'dennisscheunhage',
#  'info',
#  'popupmediaoy.fi.p.111616-9',
#  'toimisto',
#  'info',
#  'contato',
#  'contato',
#  'montichel',
#  'amy.tx.transcare',
#  'info.txmeddevice',
#  'mike.transcare',
#  'support',
#  'anniekoh.realestate',
#  'dpo',
#  'enquiry',
#  'contact',
#  'contact',
#  'romain',
#  'info',
#  'support',
#  'va',
#  'ad.pearland',
#  'mo',
#  'contact',
#  'shanicej10',
#  'careers',
#  'paytocert',
#  'nsunaga',
#  'hello',
#  'townofsterlingclerk',
#  'enquiries',
#  'info',
#  'hpf',
#  'post',
#  'dpo',
#  'enquiry',
#  'iamcatong',
#  'support',
#  'financeiro',
#  'contact',
#  'juiceduplashes',
#  'katie',
#  'dpo',
#  'enquiry',
#  'luqmanhakimproperties',
#  'hi',
#  'sales',
#  'craftcircus.supplies',
#  'dpo',
#  'enquiry',
#  'maxhuang.projects',
#  'info',
#  'chris',
#  'info',
#  'info',
#  'info',
#  'kadlecek',
#  'dpo',
#  'enquiry',
#  'ykk79000',
#  'contact',
#  'matthew',
#  'thomas',
#  'contacto',
#  'info',
#  'mccullough.brandt',
#  'poundsand',
#  'info',
#  'info',
#  'info',
#  'pptaf87',
#  'help',
#  'info',
#  'info',
#  'info',
#  'nh',
#  'search',
#  'gamil.commirmoin100',
#  'jknewchenbal',
#  'jknewschenab001',
#  'jknewschenab001',
#  'jknewschenab',
#  'service',
#  'soporte',
#  'contactkayasole',
#  'info',
#  'info',
#  'wordpress',
#  'info',
#  'info',
#  'search',
#  'inquiries',
#  'permanentmakeupsupplies',
#  'kclarkeny',
#  'information',
#  'support',
#  '713kontakt',
#  '7element13',
#  'kontakt',
#  'viet.nq90',
#  'hello',
#  'hellogographer',
#  'information',
#  'support',
#  'info',
#  'info',
#  'info',
#  'info',
#  'sales',
#  'kaleva.vl',
#  'support',
#  'customerservice',
#  'tenshoku',
#  'info',
#  'privacy',
#  'barucha',
#  'frank',
#  'info',
#  'jerryh',
#  'privacy',
#  'shaneknight',
#  'walterw',
#  'crazykabboy6',
#  'info',
#  'info',
#  'info',
#  'gabriel',
#  'hola',
#  'legal',
#  'info',
#  'k.walker',
#  'info',
#  'ayurjeet20',
#  'ragamjogja',
#  'gracie',
#  'ragamjogja',
#  'bethegoaty',
#  'hi',
#  'arganmidas.com.ua',
#  'info',
#  'biuro',
#  'rmm',
#  'atendimento',
#  'contato',
#  'hello',
#  'dogtownhots',
#  'ladlesportadv',
#  'datenschutz',
#  'hello',
#  'go88web1',
#  'admin',
#  'dsirstad',
#  'rose',
#  'alexi.delcanto',
#  'hi',
#  'order',
#  'wholesale',
#  'a-s.hagspiel',
#  'gabriele.blank',
#  'pfarramt',
#  'pfarramt',
#  'jolielaideau',
#  'info',
#  'info',
#  'info',
#  'adblinkmedia',
#  'rogerjameselsgood',
#  'contact',
#  'electronbikefrejus',
#  'magnoliamidleton34',
#  'serviceclient',
#  'support',
#  'samuelsubba077',
#  'sunakhari.darj',
#  'agnija',
#  'au',
#  'info.latvija.riga',
#  'info',
#  'info',
#  'ivo',
#  'muzejs',
#  'kontakt',
#  'kontakt',
#  'goodmarkagencies',
#  'mail',
#  'info',
#  'dataprotection',
#  'dataprotection',
#  'info',
#  'dpi.homeinspections',
#  'contact',
#  'contact',
#  'gabriel',
#  'hola',
#  'legal',
#  'ante',
#  'kevin',
#  'datenschutz',
#  'hello',
#  'kevin',
#  'info',
#  'slaughterhouzemma',
#  'goodmarkagencies',
#  'ante',
#  'gestion',
#  'naturescreationcda',
#  'post',
#  'louisa',
#  'info',
#  'gmsfpho',
#  'info',
#  'brittany',
#  'savelives',
#  'newcoppertreeboard',
#  'marketing',
#  'shop',
#  'dennis',
#  'ﬁcusgreens',
#  'adam',
#  'info',
#  'info',
#  'principalvcas',
#  'torerome',
#  'kontakt',
#  'admin',
#  'info',
#  'rustad',
#  'info',
#  'carine',
#  'hi',
#  'xxvi.supply',
#  'info',
#  'info',
#  'metrojaminan',
#  'info',
#  'info',
#  'complaints.lpt',
#  'info.loveplaytoys',
#  'ninfo.loveplaytoys',
#  'orders',
#  'info',
#  'jussi.jarvinen',
#  'sari.valasvuo',
#  'compro_team',
#  'ptsaffalyamitrautama',
#  'inquire',
#  'popolkam',
#  'info',
#  'compro_team',
#  'ptsaffalyamitrautama',
#  'kontakt',
#  'kontakt',
#  'customercare',
#  'info',
#  'ajohn',
#  'dustin',
#  'jamescostello',
#  'jdoty',
#  'msears',
#  'thethurmanater',
#  'wallacewealth',
#  'info',
#  'sales',
#  'support',
#  'info',
#  'info',
#  'contact',
#  'info',
#  'informacion',
#  'pedidos',
#  'ventapormayor',
#  'contacto',
#  'diego.cava',
#  'brad',
#  'career',
#  'info',
#  'it',
#  'comunicazione',
#  'info',
#  'info',
#  'info',
#  'enquiries',
#  'info',
#  'privacy',
#  'info',
#  'info',
#  'ashley',
#  'admin',
#  'hello',
#  'it',
#  'administracion',
#  'previni.consultoria',
#  'cairns',
#  'enquiries',
#  'info',
#  'sales',
#  'service',
#  'lezz_kantoor',
#  'glamjor',
#  'trauzeugen',
#  'rnoren',
#  'info',
#  'info',
#  'gisela.schutti',
#  'l12345',
#  'p12345',
#  'pv',
#  's1234567890',
#  'servicedesk',
#  'novellaprints',
#  'tuyhoafoods',
#  'info',
#  'cvah',
#  'info',
#  'hello',
#  'billing',
#  'jimmellsamuels',
#  'mellhost',
#  'support',
#  'admin',
#  'info',
#  'info',
#  'hello',
#  'uneimages',
#  'info',
#  'drpedro',
#  'info',
#  'info',
#  'beheer',
#  'ssdfutbolclubsrl',
#  'info',
#  'ssdfutbolclubsrl',
#  'sales',
#  'contact',
#  'contactstarnemesis',
#  'info',
#  'info',
#  'info',
#  'daniela.goette',
#  'info',
#  'baselschweizinfo',
#  'info',
#  'hello',
#  'legal',
#  'legal',
#  'contact',
#  'info',
#  'sales',
#  'futlaa.ltd',
#  'qamar',
#  'contact',
#  'benoteworthy',
#  'vanzari',
#  'futlaa.ltd',
#  'info',
#  'info',
#  'jotudescrubs',
#  'support',
#  'support',
#  'yvo',
#  'booking',
#  'info',
#  'customerservice',
#  'info',
#  'geri',
#  'info',
#  'info',
#  'info',
#  'info',
#  'hello',
#  'contacto',
#  'studiotinyloft',
#  'tanya',
#  'dan.rubio',
#  'jeral.bautista',
#  'sel.bautista',
#  'victor.pavon',
#  'arkyenpharmaceuticals99',
#  'samuelsubba077',
#  'sunakhari.darj',
#  'info',
#  'info',
#  'contact',
#  'order',
#  'info',
#  'hello',
#  'info',
#  'bookdesign',
#  'info',
#  'info',
#  'kuhrmarvin',
#  'botextra341',
#  'email',
#  'youremails',
#  'info',
#  'info',
#  'info',
#  'sales',
#  'biz',
#  'administracion',
#  'sousaku',
#  'joe',
#  'kontakt',
#  'timwarnecke0',
#  'hello',
#  'info',
#  'info',
#  'enquiries',
#  'gamil.commirmoin100',
#  'jknewchenbal',
#  'jknewschenab001',
#  'jknewschenab001',
#  'jknewschenab',
#  'admin',
#  '0001az',
#  '0003az',
#  '0005fl',
#  '0006tn',
#  '0007nj',
#  '0008il',
#  '0009co',
#  '0010mn',
#  '0014fl',
#  '0016tn',
#  '0023ga',
#  '0025gm',
#  '0031gm',
#  '0032gm',
#  '0033wi',
#  '0035tx',
#  '0038gm',
#  '0039gm',
#  '0041gm',
#  '0041mo',
#  '0042nd',
#  '0043gm',
#  '0044mn',
#  '0049wi',
#  'afascientto',
#  'ajones',
#  'bbuchholtz',
#  'bcitron',
#  'bgrinaker',
#  'bkneeshaw',
#  'bzweig',
#  'cconlee',
#  'cflom',
#  'dcoats',
#  'dgalloway',
#  'dnovak',
#  'eebsworth',
#  'eromero',
#  'jcoats',
#  'jgrinaker',
#  'jmarkowicz',
#  'jzalud',
#  'kgilbertson',
#  'khalvorson',
#  'kkimmel',
#  'lgreenhill',
#  'mgilbertson',
#  'mhixon',
#  'mstrulowitz',
#  'prosetowson',
#  'sbuchner',
#  'shixon',
#  'skimmel',
#  'support',
#  'tdalsin',
#  'tdisco',
#  'info',
#  'bobvandelm',
#  'sharecareawards',
#  'info',
#  'mehtisham235',
#  'info',
#  'info',
#  'info',
#  'appliancespartsonline',
#  'stellarlawnpest',
#  'info',
#  'ceo',
#  'office',
#  'kontakt',
#  'darren',
#  'out.patrick',
#  'patrick',
#  'info',
#  'info',
#  'allesklar',
#  'info',
#  'info',
#  'labfriendinfo',
#  'info',
#  'admin',
#  'info',
#  'info',
#  'privacy',
#  'tienda',
#  'info',
#  'bryce.supplement',
#  'contact',
#  'primas',
#  'humedalrenaca',
#  '01coversme',
#  'coverme',
#  'executives',
#  'info',
#  'watchbaoanh',
#  'rd.surreysussex',
#  'shb',
#  'servicioyatencion',
#  'labfriendinfo',
#  'americas',
#  'ann',
#  'apac',
#  'avi',
#  'camille',
#  'emea',
#  'ernie',
#  'greg',
#  'help',
#  'jarod',
#  'jason',
#  'jeff.sidfrid',
#  'jeff',
#  'lauryn',
#  'mark',
#  'marketing',
#  'media',
#  'michael',
#  'mimi',
#  'partner',
#  'partner',
#  'rahim',
#  'sarah',
#  'shannon',
#  'wade',
#  'info',
#  'lisa.timmins',
#  'americas',
#  'ann',
#  'apac',
#  'avi',
#  'camille',
#  'emea',
#  'ernie',
#  'greg',
#  'help',
#  'jarod',
#  'jason',
#  'jeff.sidfrid',
#  'jeff',
#  'lauryn',
#  'mark',
#  'marketing',
#  'media',
#  'michael',
#  'mimi',
#  'partner',
#  'partner',
#  'rahim',
#  'sarah',
#  'shannon',
#  'wade',
#  'contact',
#  'sales',
#  'support',
#  'watchbaoanh',
#  'info',
#  'contact',
#  'ernest',
#  'ngavq.hoangnammobile',
#  'caseydillow36',
#  'paving_plus',
#  'assistenza',
#  'info',
#  'cmd',
#  'gary',
#  'investorservices',
#  'spencer',
#  'dentalgroup',
#  'bdavis',
#  'fjcolombiapr',
#  'info',
#  'info',
#  'uksales',
#  'mcheryl',
#  'info',
#  'kittenishgirljess',
#  'sngsngsng09',
#  'julie',
#  'trauzeugen',
#  'bso',
#  'cej',
#  'international',
#  'info',
#  'hello',
#  'info',
#  'craftynestdesigns',
#  'info',
#  'info',
#  'revivedancewear.ca',
#  'info',
#  'info',
#  'mllegeorgesand',
#  'info',
#  'atendimento',
#  'admin',
#  'enquiry',
#  'sales',
#  'sample',
#  'support',
#  'info',
#  'form1docs',
#  'lbielby',
#  'smortimer',
#  'info',
#  'wisedent1',
#  'adrienner.art',
#  'support',
#  'info',
#  'info',
#  'hadi',
#  'info',
#  'info',
#  'info',
#  'info',
#  'info',
#  'info',
#  'info',
#  'botextra341',
#  'nagatamitra',
#  'sales',
#  'info',
#  'confioenmi8',
#  'info',
#  'estubble',
#  'thewell',
#  'info',
#  'goodnewsdaily',
#  'admin',
#  'administrator',
#  'kontakt',
#  'info',
#  'info',
#  'info',
#  'valkyriesdesigns',
#  'info',
#  'revive_coordination',
#  'lene',
#  'prodex-rgpd',
#  'rgpd',
#  'enquiries.asean',
#  'enquiries.indonesia',
#  'enquiries.malaysia',
#  'enquiries.thailand',
#  'enquiries.vietnam',
#  'enquiry',
#  'lysaght.singapore',
#  'myanmar',
#  'info',
#  'holyworld2014',
#  'info',
#  'rachel',
#  'info',
#  'annel',
#  'o.',
#  'wideanglechannel',
#  'transport',
#  'ninfo',
#  'yourinnergardenhealthcoach',
#  'info',
#  'john',
#  'bolanos',
#  'info',
#  'internacional',
#  'midia',
#  'suporte',
#  'hello',
#  'peter',
#  'smurph929',
#  'ayuda',
#  'info',
#  'info',
#  'info',
#  'info',
#  'info',
#  'contact',
#  'kaliningrad',
#  'info',
#  'biz',
#  'careers',
#  'david.bonner',
#  'info',
#  'info',
#  'info',
#  'orders',
#  'ayuda',
#  'info',
#  'info',
#  'hello',
#  'onaleerose22',
#  'alan',
#  'david.bonner',
#  'don.grieser',
#  'obivaem178',
#  'sazeqstore',
#  'support',
#  'hello',
#  'info',
#  'info',
#  'contato',
#  'loja',
#  'info',
#  'service',
#  'info',
#  'info',
#  'info',
#  'power',
#  'email',
#  'info',
#  'info',
#  'info',
#  'b.neve',
#  'familieliebherr',
#  'smc-sonthofen',
#  'info',
#  'info',
#  'botextra341',
#  'sales',
#  'talent',
#  'sales',
#  'mariarubiohandbags',
#  'nicholas.watkins',
#  'catalogs',
#  'info',
#  'info',
#  'info',
#  'sales',
#  'info',
#  'support',
#  'info',
#  'admin',
#  'mail',
#  'info',
#  'info',
#  'gandur',
#  'linstantcacao',
#  'bdrumm',
#  'columbacentre',
#  'info',
#  'info',
#  'kula',
#  'support',
#  'support',
#  'indies',
#  'support',
#  'info',
#  'sales',
#  'support',
#  'torben',
#  'contact',
#  'info',
#  'jim',
#  'caseydillow36',
#  'paving_plus',
#  'reclutamiento',
#  'admin',
#  'alguraak',
#  'mike',
#  'borundaconcrete',
#  'info',
#  'webon',
#  'st.job.bc',
#  'jules',
#  'music',
#  'sales',
#  'christopher',
#  'info',
#  'shaun',
#  'contacto',
#  'info',
#  'najmainstitute',
#  'parkrec',
#  'info',
#  'info',
#  'yuuto',
#  'admin',
#  'biuro',
#  'jessicahightower.art',
#  'editor',
#  'info',
#  'mnoriega',
#  'ballarat',
#  'breakwater',
#  'canadian',
#  'careers',
#  'condobolin',
#  'deniliquin',
#  'epsom',
#  'euroa',
#  'healesville',
#  'kilmore',
#  'kyabram',
#  'kyneton',
#  'mansfield',
#  'moama',
#  'strathfieldsaye',
#  'whitehills',
#  'info',
#  'info',
#  'lukas',
#  'stefan',
#  'christy',
#  'ithero',
#  'peakartsalive',
#  'hello',
#  'karaboclothing',
#  'support',
#  'info',
#  'info',
#  'info',
#  'botavalife',
#  'hartzelldesigns',
#  '2110jrv',
#  'wp.natt.th',
#  'contact',
#  'peakartsalive',
#  'suporte',
#  'info',
#  'ashevilleplaystoday',
#  'reservations',
#  'botavalife',
#  'info',
#  'support',
#  'suporte',
#  'hello',
#  'ksenia',
#  'admin',
#  'info',
#  'info',
#  'ashevilleplaystoday',
#  'info',
#  'info',
#  'recruitment',
#  'info',
#  'mail',
#  'info',
#  'sales',
#  'contacto',
#  'contacts',
#  'mali.lsikora',
#  'info',
#  'info',
#  'kheirandish.takin',
#  'mail',
#  'kheirandish.takin',
#  'info',
#  'info',
#  'nfo',
#  'hadrien.clouet',
#  'stuttgart',
#  'nico',
#  'info',
#  'info',
#  'info',
#  'voorbeeld',
#  'info',
#  'kontakt',
#  'mentaltraining',
#  'yourmail',
#  'customerbookings',
#  'maywang',
#  'info',
#  'info',
#  'office',
#  'support',
#  'customerbookings',
#  'hadrien.clouet',
#  'email',
#  'info',
#  'quynhthuy.lively',
#  'huyle215',
#  'info',
#  'events',
#  'jack',
#  'info',
#  'pn',
#  'herbelieve2',
#  'kontakt',
#  'vansbags.id',
#  'contactjuublie',
#  'hello',
#  'anna.nevarez',
#  'info',
#  'hello',
#  '20contact',
#  'contact',
#  'crnews.online',
#  'info',
#  'saasland',
#  'alejandro.gonzalez',
#  'amunoz',
#  'correo',
#  'dgonzalez',
#  'mariapaz.vargas',
#  'secretaria.concepcion',
#  'secretaria.coyhaique',
#  'secretaria.rancagua',
#  'secretariagiv',
#  'hello',
#  'mail',
#  'smartydayshop',
#  'privacidaddatos.aviso',
#  'mostafaapkfon',
#  'charles',
#  'getsales',
#  'contact',
#  'contact',
#  'info',
#  'gdpr',
#  'info',
#  'jornadadobem22',
#  'bfsaa',
#  'jorneantoni',
#  'mike',
#  'contato',
#  'kontakt',
#  'hello',
#  'hello',
#  'contato',
#  'comite.incoop',
#  'xyz',
#  'dani',
#  'deneice',
#  'saudphp',
#  'hello',
#  'infonctiindia',
#  'info',
#  'info',
#  'arnt.scheele',
#  'arnt',
#  'furusato',
#  'bestuur',
#  'bult',
#  'fotos',
#  'groteoptocht',
#  'info',
#  'kinderoptocht',
#  'liedjesfestival',
#  'versieringswedstrijd',
#  'website',
#  'info',
#  'media',
#  'sharon',
#  'thomas',
#  'marketing',
#  'abelard.hernandez',
#  'contato',
#  'contact',
#  'info',
#  'rob',
#  'holysmokeecoincense',
#  'manga-blog',
#  'geeksblogging',
#  'a.baginska',
#  'biuro',
#  'contact',
#  'arvid.myrold',
#  'bard.evensen',
#  'kjell.fadnes',
#  'mathias.kjaer',
#  'odd.vidar.borosund',
#  'ola.hammervoll',
#  'per.jan.nepstad',
#  'steffen.trangsrud',
#  'svein.pedersen',
#  'thomas.foslund.harila',
#  'kevin.stott',
#  'mllegeorgesand',
#  'shop',
#  'full.si',
#  'apohairs',
#  '20',
#  'apohairs',
#  'quotenwilly',
#  'support',
#  'info',
#  'lopd',
#  'reservas',
#  'towerroadbaptistchurch',
#  'admin',
#  'contact',
#  'info',
#  ...]

# %%
email_prefix_df = pd.DataFrame(email_prefix_list,columns=["email prefix"])

# %%
email_prefix_df.value_counts()[:50]
# Out:
# email prefix
# info               70353
# support             9906
# contact             9495
# hello               6302
# sales               5402
# admin               3994
# office              2446
# contato             2300
# kontakt             1876
# privacy             1846
# mail                1505
# contacto            1406
# biuro               1023
# service              999
# enquiries            843
# help                 816
# customerservice      769
# webmaster            749
# marketing            708
# hola                 704
# enteryour            665
# dpo                  590
# john                 586
# shop                 584
# post                 573
# ventas               566
# hi                   542
# orders               539
# email                523
# 20info               414
# press                391
# customercare         361
# cs                   351
# enquiry              349
# mllegeorgesand       347
# repairs              330
# comercial            300
# example              295
# team                 278
# returns              277
# legal                272
# contactus            266
# joe                  250
# geral                247
# hallo                246
# atendimento          245
# media                237
# hr                   235
# care                 216
# careers              205
# dtype: int64

# %%
email_prefix_df.shape
# Out:
# (302666, 1)

# %% [markdown]
# # Genuine Email prefix count

# %%
email_prefix_count = email_prefix_df.value_counts().rename_axis('email prefix').reset_index(name='counts')

# %%
email_prefix_count
# Out:
#           email prefix  counts
# 0                 info   70353
# 1              support    9906
# 2              contact    9495
# 3                hello    6302
# 4                sales    5402
# ...                ...     ...
# 102948  harjinderkarir       1
# 102949   haristsoukkas       1
# 102950    harish.sikka       1
# 102951        harish.p       1
# 102952        ｆｅｄｅｒｉｃｏ       1
#
# [102953 rows x 2 columns]

# %%
genuine_email_prefix = email_prefix_count[email_prefix_count['counts']<= 5]

# %%
genuine_email_prefix.head()
# Out:
#             email prefix  counts
# 2253  zakirova.alina2011       5
# 2254               misty       5
# 2255             utrecht       5
# 2256               sonja       5
# 2257    valerie.ridgeway       5

# %%
# !pip install nltk -q

# %% [markdown]
# # Clustering
#  - trying to extend the email prefix with its synonyms in order to perform cluster analysis on those extended textual dataset

# %%
common_email_prefix_df = email_prefix_count[email_prefix_count['counts']>= 10]

# %%
emails_prefix = common_email_prefix_df['email prefix'].unique()

# %%
len(emails_prefix)
# Out:
# 1292

# %%
emails_prefix
# Out:
# array(['info', 'support', 'contact', ..., 'wspolpraca', 'tj', 'deborah'],
#       dtype=object)

# %%
import nltk
nltk.download("all")
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/suman/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/extended_omw.zip.
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /home/suman/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /home/suman/nltk_data...

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize("books")
